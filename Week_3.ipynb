# %%
import pandas as pd
import numpy as np
# from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn import metrics
from sklearn import model_selection
from IPython.display import Image
import pydotplus

# %%
data = pd.read_csv('C:/Workspace/Comento_Data_Analyst/train_mdf.csv')

# %%
data.OverallQual
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
X = np.array(pd.DataFrame(data, columns=['OverallQual']))
y = np.array(pd.DataFrame(data, columns=['SalePrice']))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=None, max_leaf_nodes=None,
                                   max_features=None)     
clf = clf.fit(X_train, y_train)

# %%
# prediction = clf.predict(X_test)

# %%
# from sklearn.metrics import accuracy_score

# accuracy_score(y_test,prediction)
# Out:
# 0.0091324200913242

# %%
y_predict = clf.predict(X_train) 
score = metrics.accuracy_score(y_train, y_predict)
print(score) #1.0

y_predict = clf.predict(X_test) 
score = metrics.accuracy_score(y_test, y_predict)
print(score) #1.0
# Out:
# 0.033268101761252444
# 0.0091324200913242

# %%
feature_names = data.columns.tolist()
feature_names = feature_names[17]
target_name = np.array(['Play No', 'Play Yes'])

# %%
feature_names[17]
# Out:
# 'OverallQual'

# %%
dt_dot_data = tree.export_graphviz(clf, out_file = None,
                                  feature_names = feature_names,
                                  class_names = target_name,
                                  filled = True, rounded = True,
                                  special_characters = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-aed1ea34f479> in <module>
# ----> 1 dot_data2 = export_graphviz(X_test,        # 의사결정나무 모형 대입
#       2                                out_file = None,     # file로 변환할 것인가
#       3 #                                feature_names = iris.feature_names, # feature 이름
#       4 #                                class_names = iris.target_names,   # target 이름
#       5                                filled = True,        # 그림에 색상을 넣을것인가
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ...

# %%
dt_graph = pydotplus.graph_from_dot_data(dt_dot_data)

# %%
Image(dt_graph.create_png())
