# %%
import pandas as pd
import numpy as np
# from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn import metrics
from sklearn import model_selection
from IPython.display import Image
import pydotplus

# %%
data = pd.read_csv('C:/Workspace/Comento_Data_Analyst/train_mdf.csv')

# %%
data.OverallQual
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
# data.OverallQual = data.OverallQual.replace(1,'Very Poor')
# data.OverallQual = data.OverallQual.replace(2,'Poor')
# data.OverallQual = data.OverallQual.replace(3,'Fair')
# data.OverallQual = data.OverallQual.replace(4,'Below Average')
# data.OverallQual = data.OverallQual.replace(5,'Average')
# data.OverallQual = data.OverallQual.replace(6,'Above Average')
# data.OverallQual = data.OverallQual.replace(7,'Good')
# data.OverallQual = data.OverallQual.replace(8,'Very Good')
# data.OverallQual = data.OverallQual.replace(9,'Excellent')
# data.OverallQual = data.OverallQual.replace(10,'Very Excellent')

# %%
data.OverallQual
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
X = np.array(pd.DataFrame(data, columns=['OverallQual']))
y = np.array(pd.DataFrame(data, columns=['SalePrice']))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth=None, max_leaf_nodes=None,
                                   max_features=None)     
clf = clf.fit(X_train, y_train)

# %%
# prediction = clf.predict(X_test)

# %%
# from sklearn.metrics import accuracy_score

# accuracy_score(y_test,prediction)

# %%
y_predict = clf.predict(X_train) 
score = metrics.accuracy_score(y_train, y_predict)
print(score) #1.0

y_predict = clf.predict(X_test) 
score = metrics.accuracy_score(y_test, y_predict)
print(score) #1.0
# Out:
# 0.030332681017612523
# 0.0182648401826484

# %%
feature_names = data.columns.tolist()
feature_names = feature_names[17]
target_name = np.array(['Very Poor', ]) #종속변수가 범주형이여야함.......

# %%
dt_dot_data = export_graphviz(clf, out_file = None,
                                  feature_names = feature_names,
                                  class_names = target_name,
                                  filled = True, rounded = True,
                                  special_characters = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-ccecdc3502d0> in <module>
# ----> 1 dt_dot_data = export_graphviz(clf, out_file = None,
#       2                                   feature_names = feature_names,
#       3                                   class_names = target_name,
#       4                                   filled = True, rounded = True,
#       5                                   special_characters = True)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ...

# %%
dt_graph = pydotplus.graph_from_dot_data(dt_dot_data)

# %%
Image(dt_graph.create_png())
