# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Workspace/Comento_Data_Analyst/4th_data.csv')

# %%
data[data['taskID'] == 'InformClientWrongPlace']
# Out:
#        caseID                  taskID originator eventtype         timestamp  \
# 72          6  InformClientWrongPlace     Monica  complete  1970-01-03 02:29
# 74          7  InformClientWrongPlace     Monica  complete  1970-01-07 09:21
# 148        13  InformClientWrongPlace     Monica  complete  1970-01-02 12:22
# 519        40  InformClientWrongPlace     Monica  complete  1970-01-06 05:07
# 809        61  InformClientWrongPlace     Monica  complete  1970-01-06 12:40
# ...       ...                     ...        ...       ...               ...
# 11492     871  InformClientWrongPlace     Monica  complete  1970-01-01 21:06
# 11650     883  InformClientWrongPlace     Monica  complete  1970-01-06 00:20
# 12132     918  InformClientWrongPlace     Monica  complete  1970-01-07 20:52
# 12454     942  InformClientWrongPlace     Monica  complete  1970-01-07 13:14
# 12785     966  InformClientWrongPlace       Dian  complete  1970-01-06 02:35
#
# ...
